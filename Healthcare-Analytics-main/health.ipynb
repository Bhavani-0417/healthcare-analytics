# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
test
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 3        318442              6                  a                   6
# 4        318443             28                  b                  11
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
train.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
test.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# ...

# %%
train.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
test.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137057 entries, 0 to 137056
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            137057 non-null  int64
#  1   Hospital_code                      137057 non-null  int64
#  2   Hospital_type_code                 137057 non-null  object
#  3   City_Code_Hospital                 137057 non-null  int64
#  4   Hospital_region_code               137057 non-null  object
#  5   Available Extra Rooms in Hospital  137057 non-null  int64
#  6   Department                         137057 non-null  object
#  7   Ward_Type                          137057 non-null  object
#  8   Ward_Facility_Code                 137057 non-null  object
#  9   Bed Grade                          137022 non-null  float64
#  10  patientid                          137057 non-null  int64
# ...

# %%
train.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
test.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                              35
# patientid                               0
# City_Code_Patient                    2157
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# dtype: int64

# %%
test.dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# case_id                              0
# Hospital_code                        0
# Hospital_type_code                   0
# City_Code_Hospital                   0
# Hospital_region_code                 0
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Type                            0
# Ward_Facility_Code                   0
# Bed Grade                            0
# patientid                            0
# City_Code_Patient                    0
# Type of Admission                    0
# Severity of Illness                  0
# Visitors with Patient                0
# Age                                  0
# Admission_Deposit                    0
# Stay                                 0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# case_id                              0
# Hospital_code                        0
# Hospital_type_code                   0
# City_Code_Hospital                   0
# Hospital_region_code                 0
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Type                            0
# Ward_Facility_Code                   0
# Bed Grade                            0
# patientid                            0
# City_Code_Patient                    0
# Type of Admission                    0
# Severity of Illness                  0
# Visitors with Patient                0
# Age                                  0
# Admission_Deposit                    0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
# Identify object columns
categorical_cols =train.select_dtypes(include=['object']).columns

# Apply Label Encoding
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    label_encoders[col] = le

# %%
# Identify object columns
categorical_cols =test.select_dtypes(include=['object']).columns

# Apply Label Encoding
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    test[col] = le.fit_transform(test[col])
    label_encoders[col] = le

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313793 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            313793 non-null  int64
#  1   Hospital_code                      313793 non-null  int64
#  2   Hospital_type_code                 313793 non-null  int32
#  3   City_Code_Hospital                 313793 non-null  int64
#  4   Hospital_region_code               313793 non-null  int32
#  5   Available Extra Rooms in Hospital  313793 non-null  int64
#  6   Department                         313793 non-null  int32
#  7   Ward_Type                          313793 non-null  int32
#  8   Ward_Facility_Code                 313793 non-null  int32
#  9   Bed Grade                          313793 non-null  float64
#  10  patientid                          313793 non-null  int64
# ...

# %%
train['Stay'].unique()
# Out:
# array([ 0,  4,  3,  1,  5,  2,  7, 10,  8,  6,  9])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134865 entries, 0 to 137056
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            134865 non-null  int64
#  1   Hospital_code                      134865 non-null  int64
#  2   Hospital_type_code                 134865 non-null  int32
#  3   City_Code_Hospital                 134865 non-null  int64
#  4   Hospital_region_code               134865 non-null  int32
#  5   Available Extra Rooms in Hospital  134865 non-null  int64
#  6   Department                         134865 non-null  int32
#  7   Ward_Type                          134865 non-null  int32
#  8   Ward_Facility_Code                 134865 non-null  int32
#  9   Bed Grade                          134865 non-null  float64
#  10  patientid                          134865 non-null  int64
# ...

# %%
test1=pd.read_csv('test_prediction.csv')

# %%
train.shape
# Out:
# (313793, 18)

# %%
test1.shape
# Out:
# (134865, 18)

# %%
"""
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Step 2: Preprocessing (Assuming the last column is the target)
X_train = train.iloc[:, :-1]  # Features
y_train = train.iloc[:, -1]   # Target

X_test = test1.iloc[:, :-1]    
y_test = test1.iloc[:, -1]
# Step 3: Standardize the data (if necessary)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 4: Train the model (Using XGBoost)
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Step 5: Make predictions on test data
y_pred = model.predict(X_test)

# If the test.csv has actual labels, evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
"""
# Out:
# '\nimport pandas as pd\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.preprocessing import StandardScaler\nimport xgboost as xgb\nfrom sklearn.metrics import accuracy_score\n\n# Step 2: Preprocessing (Assuming the last column is the target)\nX_train = train.iloc[:, :-1]  # Features\ny_train = train.iloc[:, -1]   # Target\n\nX_test = test1.iloc[:, :-1]    \ny_test = test1.iloc[:, -1]\n# Step 3: Standardize the data (if necessary)\nscaler = StandardScaler()\nX_train = scaler.fit_transform(X_train)\nX_test = scaler.transform(X_test)\n\n# Step 4: Train the model (Using XGBoost)\nmodel = xgb.XGBClassifier()\nmodel.fit(X_train, y_train)\n\n# Step 5: Make predictions on test data\ny_pred = model.predict(X_test)\n\n# If the test.csv has actual labels, evaluate the model\naccuracy = accuracy_score(y_test, y_pred)\nprint(f"Model Accuracy: {accuracy:.2f}")\n'

# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Step 1: Generate Synthetic Data
X, y = make_classification(
    n_samples=32000, 
    n_features=17, 
    n_classes=11, 
    n_informative=17,
    n_redundant=0,
    n_repeated=0,# Increase informative features
    n_clusters_per_class=2,  # Keep clusters per class default (or adjust if needed)
    random_state=42
)

# Convert to DataFrame
df = pd.DataFrame(X, columns=[f'Feature_{i}' for i in range(X.shape[1])])
df['Target'] = y  # Add target column

# Step 2: Split into train and test sets
train, test1 = train_test_split(df, test_size=0.2, random_state=42)

# Step 3: Separate features and target
X_train = train.iloc[:, :-1]  # Features
y_train = train.iloc[:, -1].values  # Target as NumPy array

X_test = test1.iloc[:, :-1]    
y_test = test1.iloc[:, -1].values  # Target as NumPy array

# Step 4: Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 5: Train the XGBoost model
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Step 6: Make predictions
y_pred = model.predict(X_test)

# Step 7: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 5
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.preprocessing import StandardScaler
# ----> 5 import xgboost as xgb
#       6 from sklearn.metrics import accuracy_score
#       8 # Step 1: Generate Synthetic Data
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Step 2: Preprocessing (Assuming the last column is the target)
X_train = train.iloc[:, :-1]  # Features
y_train = train.iloc[:, -1]   # Target

X_test = test1.iloc[:, :-1]    
y_test = test1.iloc[:, -1]

# Step 3: Standardize the data (if necessary)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 4: Train the model (Using Random Forest)
model = RandomForestClassifier(
    n_estimators=200,  # Number of trees
    max_depth=5,       # Maximum depth of each tree
    random_state=42,   # Ensuring reproducibility
    n_jobs=-1          # Use all available CPU cores
)
model.fit(X_train, y_train)

# Step 5: Make predictions on test data
y_pred = model.predict(X_test)

# If the test.csv has actual labels, evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# Use MinMaxScaler instead of StandardScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the Random Forest with better hyperparameters
model1 = RandomForestClassifier(
    n_estimators=300,  # More trees for better performance
    max_depth=10,  # Increase depth for capturing more patterns
    min_samples_split=5,  # Prevent overfitting
    min_samples_leaf=2,  # Minimum samples per leaf
    max_features='sqrt',  # Consider sqrt of features per split
    random_state=42,
    n_jobs=-1
)
model1.fit(X_train, y_train)

# Predictions
y_pred = model1.predict(X_test)

# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
print(f"Improved Model Accuracy: {accuracy:.2f}")

# %%
import pickle
pickle.dump(le,open('encoder.pkl','wb'))
pickle.dump(model,open('model.pkl','wb'))
